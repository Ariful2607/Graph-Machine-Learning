# %%
import pandas as pd

dataset = pd.read_csv('World Development Indicators.csv')
dataset.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  \
# 0  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 1  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 2           Rural population (% of total population)     SP.RUR.TOTL.ZS
# 3                 Rural population growth (annual %)     SP.RUR.TOTL.ZG
# 4                                   Rural population        SP.RUR.TOTL
#
#         1960          1961          1962          1963          1964  \
# 0        NaN           NaN           NaN           NaN           NaN
# 1        NaN           NaN           NaN           NaN           NaN
# 2     49.224     49.239000     49.254000     49.270000     49.285000
# 3        NaN      1.216904      1.357405      1.236021      1.108309
# 4  27035.000  27366.000000  27740.000000  28085.000000  28398.000000
#
#           1965  ...          2016          2017          2018          2019  \
# 0          NaN  ...      0.085188      0.079480      0.076267      0.104098
# 1          NaN  ...      0.335550      0.297792      0.311423      0.350670
# 2     49.30000  ...     56.808000     56.707000     56.589000     56.454000
# 3      1.01602  ...      0.610610     -0.171763     -0.048666      0.030824
# 4  28688.00000  ...  61766.000000  61660.000000  61630.000000  61649.000000
#
#            2020          2021          2022          2023  2024  Unnamed: 69
# 0      0.069199      0.102736      0.228271      0.117845   NaN          NaN
# 1      0.339582      0.353604      0.332377      0.328433   NaN          NaN
# 2     56.303000     56.134000     55.948000     55.746000   NaN          NaN
# 3     -0.832340     -1.121778     -0.693813     -0.316968   NaN          NaN
# 4  61138.000000  60456.000000  60038.000000  59848.000000   NaN          NaN
#
# [5 rows x 70 columns]

# %%
dataset = dataset[dataset['Country Name'] == 'Indonesia']
dataset
# Out:
#      Country Name Country Code  \
# 3816    Indonesia          IDN
# 3817    Indonesia          IDN
# 3818    Indonesia          IDN
# 3819    Indonesia          IDN
# 3820    Indonesia          IDN
# 3821    Indonesia          IDN
# 3822    Indonesia          IDN
# 3823    Indonesia          IDN
# 3824    Indonesia          IDN
# 3825    Indonesia          IDN
# 3826    Indonesia          IDN
# 3827    Indonesia          IDN
# 3828    Indonesia          IDN
# 3829    Indonesia          IDN
# 3830    Indonesia          IDN
# 3831    Indonesia          IDN
# 3832    Indonesia          IDN
# 3833    Indonesia          IDN
# 3834    Indonesia          IDN
# 3835    Indonesia          IDN
# 3836    Indonesia          IDN
# 3837    Indonesia          IDN
# 3838    Indonesia          IDN
# 3839    Indonesia          IDN
# 3840    Indonesia          IDN
# 3841    Indonesia          IDN
# 3842    Indonesia          IDN
# 3843    Indonesia          IDN
# 3844    Indonesia          IDN
# 3845    Indonesia          IDN
# 3846    Indonesia          IDN
# 3847    Indonesia          IDN
# 3848    Indonesia          IDN
# 3849    Indonesia          IDN
# 3850    Indonesia          IDN
# 3851    Indonesia          IDN
#
#                                          Indicator Name     Indicator Code  \
# 3816  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 3817  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 3818           Rural population (% of total population)     SP.RUR.TOTL.ZS
# 3819                 Rural population growth (annual %)     SP.RUR.TOTL.ZG
# 3820                                   Rural population        SP.RUR.TOTL
# 3821  Employment in agriculture (% of total employme...     SL.AGR.EMPL.ZS
# 3822  Employment in agriculture, male (% of male emp...  SL.AGR.EMPL.MA.ZS
# 3823  Employment in agriculture, female (% of female...  SL.AGR.EMPL.FE.ZS
# 3824  Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.ZS
# 3825  Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.CD
# 3826  Annual freshwater withdrawals, agriculture (% ...     ER.H2O.FWAG.ZS
# 3827  Rural population living in areas where elevati...  EN.POP.EL5M.RU.ZS
# 3828  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3829                      Cereal yield (kg per hectare)     AG.YLD.CREL.KG
# 3830                              Surface area (sq. km)     AG.SRF.TOTL.K2
# 3831       Livestock production index (2014-2016 = 100)     AG.PRD.LVSK.XD
# 3832            Food production index (2014-2016 = 100)     AG.PRD.FOOD.XD
# 3833            Crop production index (2014-2016 = 100)     AG.PRD.CROP.XD
# 3834                    Cereal production (metric tons)     AG.PRD.CREL.MT
# 3835                           Rural land area (sq. km)  AG.LND.TOTL.RU.K2
# 3836                                 Land area (sq. km)     AG.LND.TOTL.K2
# 3837       Average precipitation in depth (mm per year)     AG.LND.PRCP.MM
# 3838  Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 3839                       Forest area (% of land area)     AG.LND.FRST.ZS
# 3840                               Forest area (sq. km)     AG.LND.FRST.K2
# 3841  Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.ZS
# 3842  Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.K2
# 3843                Permanent cropland (% of land area)     AG.LND.CROP.ZS
# 3844            Land under cereal production (hectares)     AG.LND.CREL.HA
# 3845                       Arable land (% of land area)     AG.LND.ARBL.ZS
# 3846                  Arable land (hectares per person)  AG.LND.ARBL.HA.PC
# 3847                             Arable land (hectares)     AG.LND.ARBL.HA
# 3848                 Agricultural land (% of land area)     AG.LND.AGRI.ZS
# 3849                         Agricultural land (sq. km)     AG.LND.AGRI.K2
# 3850  Fertilizer consumption (kilograms per hectare ...     AG.CON.FERT.ZS
# 3851  Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS
#
#               1960          1961          1962          1963          1964  \
# 3816           NaN           NaN  4.556937e+01           NaN           NaN
# 3817           NaN           NaN           NaN           NaN           NaN
# 3818  8.541400e+01  8.517900e+01  8.494200e+01  8.470100e+01  8.445700e+01
# 3819           NaN  2.511221e+00  2.528359e+00  2.540970e+00  2.567053e+00
# 3820  7.541720e+07  7.733508e+07  7.931532e+07  8.135652e+07  8.347202e+07
# 3821           NaN           NaN           NaN           NaN           NaN
# 3822           NaN           NaN           NaN           NaN           NaN
# 3823           NaN           NaN           NaN           NaN           NaN
# 3824           NaN           NaN           NaN           NaN           NaN
# 3825           NaN           NaN           NaN           NaN           NaN
# 3826           NaN           NaN           NaN           NaN           NaN
# 3827           NaN           NaN           NaN           NaN           NaN
# 3828           NaN           NaN           NaN           NaN           NaN
# 3829           NaN  1.541700e+03  1.553500e+03  1.501900e+03  1.512800e+03
# 3830           NaN  1.910930e+06  1.910930e+06  1.910930e+06  1.910930e+06
# 3831           NaN  1.305000e+01  1.370000e+01  1.366000e+01  1.414000e+01
# 3843  1.425951e+01  1.435929e+01  1.427909e+01  1.450299e+01           NaN
# 3844  1.428877e+07  1.363700e+07  1.339951e+07  1.451990e+07           NaN
# 3845  9.555696e+00  9.555696e+00  9.479775e+00  9.479775e+00           NaN
# 3846  9.651752e-02  9.570079e-02  9.502885e-02           NaN           NaN
# 3847  2.630000e+07  2.630000e+07  2.630000e+07           NaN           NaN
# 3848  2.967401e+01  2.977378e+01  2.957111e+01  2.979501e+01           NaN
# 3849  6.410000e+05  6.430000e+05  6.460000e+05           NaN           NaN
# 3850  3.020446e+02  3.334425e+02  3.780288e+02  3.083308e+02           NaN
# 3851  1.141130e+02  1.218631e+02  1.430638e+02  1.218548e+02           NaN
#
#       2024  Unnamed: 69
# 3816   NaN          NaN
# 3817   NaN          NaN
# 3818   NaN          NaN
# 3819   NaN          NaN
# 3820   NaN          NaN
# 3821   NaN          NaN
# 3822   NaN          NaN
# 3823   NaN          NaN
# 3824   NaN          NaN
# 3825   NaN          NaN
# 3826   NaN          NaN
# 3827   NaN          NaN
# 3828   NaN          NaN
# 3829   NaN          NaN
# 3830   NaN          NaN
# 3831   NaN          NaN
# 3832   NaN          NaN
# 3833   NaN          NaN
# 3834   NaN          NaN
# 3835   NaN          NaN
# 3836   NaN          NaN
# 3837   NaN          NaN
# 3838   NaN          NaN
# 3839   NaN          NaN
# 3840   NaN          NaN
# 3841   NaN          NaN
# 3842   NaN          NaN
# 3843   NaN          NaN
# 3844   NaN          NaN
# 3845   NaN          NaN
# 3846   NaN          NaN
# 3847   NaN          NaN
# 3848   NaN          NaN
# 3849   NaN          NaN
# 3850   NaN          NaN
# 3851   NaN          NaN
#
# [36 rows x 70 columns]

# %%
dataset = dataset.drop(columns=['Country Name', 'Country Code', 'Indicator Code'])
dataset
# Out:
#                                          Indicator Name          1960  \
# 3816  Agricultural raw materials exports (% of merch...           NaN
# 3817  Agricultural raw materials imports (% of merch...           NaN
# 3818           Rural population (% of total population)  8.541400e+01
# 3819                 Rural population growth (annual %)           NaN
# 3820                                   Rural population  7.541720e+07
# 3821  Employment in agriculture (% of total employme...           NaN
# 3822  Employment in agriculture, male (% of male emp...           NaN
# 3823  Employment in agriculture, female (% of female...           NaN
# 3824  Agriculture, forestry, and fishing, value adde...           NaN
# 3825  Agriculture, forestry, and fishing, value adde...           NaN
# 3826  Annual freshwater withdrawals, agriculture (% ...           NaN
# 3827  Rural population living in areas where elevati...           NaN
# 3828  Access to electricity, rural (% of rural popul...           NaN
# 3829                      Cereal yield (kg per hectare)           NaN
# 3830                              Surface area (sq. km)           NaN
# 3831       Livestock production index (2014-2016 = 100)           NaN
# 3832            Food production index (2014-2016 = 100)           NaN
# 3833            Crop production index (2014-2016 = 100)           NaN
# 3834                    Cereal production (metric tons)           NaN
# 3835                           Rural land area (sq. km)           NaN
# 3836                                 Land area (sq. km)           NaN
# 3837       Average precipitation in depth (mm per year)           NaN
# 3838  Agricultural irrigated land (% of total agricu...           NaN
# 3839                       Forest area (% of land area)           NaN
# 3840                               Forest area (sq. km)           NaN
# 3841  Rural land area where elevation is below 5 met...           NaN
# 3827           NaN           NaN   NaN          NaN
# 3828  9.820000e+01  9.860000e+01   NaN          NaN
# 3829  5.393500e+03           NaN   NaN          NaN
# 3830  1.916907e+06           NaN   NaN          NaN
# 3831  1.899900e+02           NaN   NaN          NaN
# 3832  1.171400e+02           NaN   NaN          NaN
# 3833  1.114100e+02           NaN   NaN          NaN
# 3834  7.831298e+07           NaN   NaN          NaN
# 3835           NaN           NaN   NaN          NaN
# 3836  1.892555e+06           NaN   NaN          NaN
# 3837           NaN           NaN   NaN          NaN
# 3838           NaN           NaN   NaN          NaN
# 3839  4.804199e+01           NaN   NaN          NaN
# 3840  9.092213e+05           NaN   NaN          NaN
# 3841           NaN           NaN   NaN          NaN
# 3842           NaN           NaN   NaN          NaN
# 3843  1.450299e+01           NaN   NaN          NaN
# 3844  1.451990e+07           NaN   NaN          NaN
# 3845  9.479775e+00           NaN   NaN          NaN
# 3846           NaN           NaN   NaN          NaN
# 3847           NaN           NaN   NaN          NaN
# 3848  2.979501e+01           NaN   NaN          NaN
# 3849           NaN           NaN   NaN          NaN
# 3850  3.083308e+02           NaN   NaN          NaN
# 3851  1.218548e+02           NaN   NaN          NaN
#
# [36 rows x 67 columns]

# %%
# Mengubah kolom tahun menjadi indeks
dataset = dataset.set_index('Indicator Name').T
dataset.head()
# Out:
# Indicator Name  Agricultural raw materials exports (% of merchandise exports)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                    45.569375
# 1963                                                          NaN
# 1964                                                          NaN
#
# Indicator Name  Agricultural raw materials imports (% of merchandise imports)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
#
# Indicator Name  Rural population (% of total population)  \
# 1960                                              85.414
# 1961                                              85.179
# 1962                                              84.942
# 1963                                              84.701
# 1964                                              84.457
#
# Indicator Name  Rural population growth (annual %)  Rural population  \
# 1960                                           NaN        75417205.0
# 1961                                      2.511221        77335078.0
# 1962                                      2.528359        79315315.0
# 1963                                      2.540970        81356517.0
# 1964                                      2.567053        83472019.0
#
# Indicator Name  Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
#
# Indicator Name  Employment in agriculture, male (% of male employment) (modeled ILO estimate)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
#
# Indicator Name  Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
#
# Indicator Name  Agriculture, forestry, and fishing, value added (% of GDP)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
#
# Indicator Name  Agriculture, forestry, and fishing, value added (current US$)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
#
# Indicator Name  ...  \
# 1960            ...
# 1961            ...
# 1962            ...
# 1963            ...
# 1964            ...
#
# Indicator Name  Rural land area where elevation is below 5 meters (sq. km)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
#
# Indicator Name  Permanent cropland (% of land area)  \
# 1960                                            NaN
# 1961                                       2.423805
# 1962                                       2.444223
# 1963                                       2.481758
# 1964                                       2.463091
#
# Indicator Name  Land under cereal production (hectares)  \
# 1960                                                NaN
# 1961                                          9319000.0
# 1962                                         10458000.0
# 1963                                          9290000.0
# 1964                                         10626000.0
#
# Indicator Name  Arable land (% of land area)  \
# 1960                                     NaN
# 1961                                8.049722
# 1962                                8.132244
# 1963                                8.214766
# 1964                                8.297287
#
# Indicator Name  Arable land (hectares per person)  Arable land (hectares)  \
# 1960                                          NaN                     NaN
# 1961                                     0.198257              18000000.0
# 1962                                     0.192769              18000000.0
# 1963                                     0.187400              18000000.0
# 1964                                     0.182124              18000000.0
#
# Indicator Name  Agricultural land (% of land area)  \
# 1960                                           NaN
# 1961                                     17.238929
# 1962                                     17.341869
# 1963                                     17.461926
# 1964                                     17.525781
#
# Indicator Name  Agricultural land (sq. km)  \
# 1960                                   NaN
# 1961                              386000.0
# 1962                              386000.0
# 1963                              385500.0
# 1964                              385500.0
#
# Indicator Name  Fertilizer consumption (kilograms per hectare of arable land)  \
# 1960                                                          NaN
# 1961                                                     9.325475
# 1962                                                    10.140829
# 1963                                                     8.735606
# 1964                                                     6.402851
#
# Indicator Name  Fertilizer consumption (% of fertilizer production)
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                   866.666667
# 1964                                                   209.221739
#
# [5 rows x 36 columns]

# %%
dataset
# Out:
# Indicator Name  Agricultural raw materials exports (% of merchandise exports)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                    45.569375
# 1963                                                          NaN
# 1964                                                          NaN
# ...                                                           ...
# 2021                                                     4.625106
# 2022                                                     3.760302
# 2023                                                     3.705784
# 2024                                                          NaN
# Unnamed: 69                                                   NaN
#
# Indicator Name  Agricultural raw materials imports (% of merchandise imports)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
# ...                                                           ...
# 2021                                                     2.645862
# 2022                                                     2.374136
# 2023                                                     1.984321
# 2024                                                          NaN
# Unnamed: 69                                                   NaN
#
# Indicator Name  Rural population (% of total population)  \
# 1960                                              85.414
# 1961                                              85.179
# 1962                                              84.942
# 1963                                              84.701
# 1964                                              84.457
# ...                                                  ...
# 2021                                              42.710
# 2022                                              42.066
# 2023                                              41.428
# 2024                                                 NaN
# Unnamed: 69                                          NaN
#
# Indicator Name  Rural population growth (annual %)  Rural population  \
# 1960                                           NaN        75417205.0
# 1961                                      2.511221        77335078.0
# 1962                                      2.528359        79315315.0
# 1963                                      2.540970        81356517.0
# 1964                                      2.567053        83472019.0
# ...                                            ...               ...
# 2021                                     -0.803520       118203364.0
# 2022                                     -0.773277       117292850.0
# 2023                                     -0.685617       116491421.0
# 2024                                           NaN               NaN
# Unnamed: 69                                    NaN               NaN
#
# Indicator Name  Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
# ...                                                           ...
# 2021                                                    28.987200
# 2022                                                    29.284862
# 2023                                                    28.768484
# 2024                                                          NaN
# Unnamed: 69                                                   NaN
#
# Indicator Name  Employment in agriculture, male (% of male employment) (modeled ILO estimate)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
# ...                                                           ...
# 2021                                                    30.954980
# 2022                                                    31.061260
# 2023                                                    30.491824
# 2024                                                          NaN
# Unnamed: 69                                                   NaN
#
# Indicator Name  Employment in agriculture, female (% of female employment) (modeled ILO estimate)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
# ...                                                           ...
# 2021                                                    26.024084
# 2022                                                    26.557243
# 2023                                                    26.120236
# 2024                                                          NaN
# Unnamed: 69                                                   NaN
#
# Indicator Name  Agriculture, forestry, and fishing, value added (% of GDP)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
# ...                                                           ...
# 2021                                                    13.280169
# 2022                                                    12.399884
# 2023                                                    12.529307
# 2024                                                          NaN
# Unnamed: 69                                                   NaN
#
# Indicator Name  Agriculture, forestry, and fishing, value added (current US$)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
# ...                                                           ...
# 2021                                                 1.575705e+11
# 2022                                                 1.635639e+11
# 2023                                                 1.717982e+11
# 2024                                                          NaN
# Unnamed: 69                                                   NaN
#
# Indicator Name  ...  \
# 1960            ...
# 1961            ...
# 1962            ...
# 1963            ...
# 1964            ...
# ...             ...
# 2021            ...
# 2022            ...
# 2023            ...
# 2024            ...
# Unnamed: 69     ...
#
# Indicator Name  Rural land area where elevation is below 5 meters (sq. km)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
# ...                                                           ...
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# 2024                                                          NaN
# Unnamed: 69                                                   NaN
#
# Indicator Name  Permanent cropland (% of land area)  \
# 1960                                            NaN
# 1961                                       2.423805
# 1962                                       2.444223
# 1963                                       2.481758
# 1964                                       2.463091
# ...                                             ...
# 2021                                      14.279088
# 2022                                      14.502990
# 2023                                            NaN
# 2024                                            NaN
# Unnamed: 69                                     NaN
#
# Indicator Name  Land under cereal production (hectares)  \
# 1960                                                NaN
# 1961                                          9319000.0
# 1962                                         10458000.0
# 1963                                          9290000.0
# 1964                                         10626000.0
# ...                                                 ...
# 2021                                         13399507.0
# 2022                                         14519903.0
# 2023                                                NaN
# 2024                                                NaN
# Unnamed: 69                                         NaN
#
# Indicator Name  Arable land (% of land area)  \
# 1960                                     NaN
# 1961                                8.049722
# 1962                                8.132244
# 1963                                8.214766
# 1964                                8.297287
# ...                                      ...
# 2021                                9.479775
# 2022                                9.479775
# 2023                                     NaN
# 2024                                     NaN
# Unnamed: 69                              NaN
#
# Indicator Name  Arable land (hectares per person)  Arable land (hectares)  \
# 1960                                          NaN                     NaN
# 1961                                     0.198257              18000000.0
# 1962                                     0.192769              18000000.0
# 1963                                     0.187400              18000000.0
# 1964                                     0.182124              18000000.0
# ...                                           ...                     ...
# 2021                                     0.095029              26300000.0
# 2022                                          NaN                     NaN
# 2023                                          NaN                     NaN
# 2024                                          NaN                     NaN
# Unnamed: 69                                   NaN                     NaN
#
# Indicator Name  Agricultural land (% of land area)  \
# 1960                                           NaN
# 1961                                     17.238929
# 1962                                     17.341869
# 1963                                     17.461926
# 1964                                     17.525781
# ...                                            ...
# 2021                                     29.571111
# 2022                                     29.795012
# 2023                                           NaN
# 2024                                           NaN
# Unnamed: 69                                    NaN
#
# Indicator Name  Agricultural land (sq. km)  \
# 1960                                   NaN
# 1961                              386000.0
# 1962                              386000.0
# 1963                              385500.0
# 1964                              385500.0
# ...                                    ...
# 2021                              646000.0
# 2022                                   NaN
# 2023                                   NaN
# 2024                                   NaN
# Unnamed: 69                            NaN
#
# Indicator Name  Fertilizer consumption (kilograms per hectare of arable land)  \
# 1960                                                          NaN
# 1961                                                     9.325475
# 1962                                                    10.140829
# 1963                                                     8.735606
# 1964                                                     6.402851
# ...                                                           ...
# 2021                                                   378.028765
# 2022                                                   308.330786
# 2023                                                          NaN
# 2024                                                          NaN
# Unnamed: 69                                                   NaN
#
# Indicator Name  Fertilizer consumption (% of fertilizer production)
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                   866.666667
# 1964                                                   209.221739
# ...                                                           ...
# 2021                                                   143.063757
# 2022                                                   121.854802
# 2023                                                          NaN
# 2024                                                          NaN
# Unnamed: 69                                                   NaN
#
# [66 rows x 36 columns]

# %%
import torch
from torch_geometric.data import Data

node_features = torch.tensor(dataset['Cereal yield (kg per hectare)'].dropna().values, dtype=torch.float).view(-1, 1)

# Membuat edge connections (contoh: hubungan antar tahun secara berurutan)
num_nodes = node_features.size(0)
edge_index = torch.tensor([[i, i + 1] for i in range(num_nodes - 1)] + [[i + 1, i] for i in range(num_nodes - 1)], dtype=torch.long).t()

# Membuat label (jika ada, misalnya prediksi kategori tertentu)
labels = torch.zeros(num_nodes, dtype=torch.long)

# Membuat objek graf
data = Data(x=node_features, edge_index=edge_index, y=labels)

print(data)
# Out:
# Data(x=[62, 1], edge_index=[2, 122], y=[62])

# %%
import torch
from torch_geometric.nn import GCNConv

import torch.nn.functional as F
import matplotlib.pyplot as plt

# Definisikan model GNN
class GNN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GNN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x

# Inisialisasi model, optimizer, dan loss function
input_dim = node_features.size(1)
hidden_dim = 16
output_dim = 1
model = GNN(input_dim, hidden_dim, output_dim)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
loss_fn = torch.nn.MSELoss()

# Data untuk pelatihan
x = node_features
y = node_features  # Menggunakan data asli sebagai target
edge_index = edge_index

# Pelatihan model
model.train()
for epoch in range(200):
    optimizer.zero_grad()
    out = model(x, edge_index)
    loss = loss_fn(out, y)
    loss.backward()
    optimizer.step()
    if epoch % 10 == 0:
        print(f'Epoch {epoch}, Loss: {loss.item()}')

# Prediksi
model.eval()
predictions = model(x, edge_index).detach().numpy()
# Out:
# Epoch 0, Loss: 4740645.5
# Epoch 10, Loss: 434053.8125
# Epoch 20, Loss: 201424.640625
# Epoch 30, Loss: 77563.46875
# Epoch 40, Loss: 34553.91796875
# Epoch 50, Loss: 19921.373046875
# Epoch 60, Loss: 15317.8046875
# Epoch 70, Loss: 11384.990234375
# Epoch 80, Loss: 11886.076171875
# Epoch 90, Loss: 11062.169921875
# Epoch 100, Loss: 11108.7392578125
# Epoch 110, Loss: 11075.15625
# Epoch 120, Loss: 11042.6328125
# Epoch 130, Loss: 11045.42578125
# Epoch 140, Loss: 11044.107421875
# Epoch 150, Loss: 11042.5517578125
# Epoch 160, Loss: 11042.4970703125
# Epoch 170, Loss: 11042.5322265625
# Epoch 180, Loss: 11042.474609375
# Epoch 190, Loss: 11042.4482421875

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Hitung RMSE
rmse = np.sqrt(mean_squared_error(y.numpy(), predictions))
print(f'RMSE: {rmse}')
# Out:
# RMSE: 105.08309119305304

# %%
# Tampilkan hasil prediksi dalam grafik dengan time step berupa tahun
plt.figure(figsize=(10, 6))

# Gunakan indeks dataset (tahun) sebagai sumbu x
# Bersihkan indeks dataset dengan menghapus nilai yang tidak dapat dikonversi ke integer
dataset_cleaned = dataset[dataset.index.str.isnumeric()]
years = dataset_cleaned.index.astype(int)  # Pastikan indeks berupa integer (tahun)

# Ensure years matches the length of y and predictions
years = years[:len(y.numpy())]

plt.plot(years, y.numpy(), label='Actual', marker='o')
plt.plot(years, predictions, label='Predicted', marker='x')

plt.xlabel('Year')
plt.ylabel('Cereal Yield (kg per hectare)')
plt.title('GNN Prediction of Cereal Yield')
plt.legend()
plt.show()

# %%
# Forecast future values
forecast_horizon = 10
historical_mean = node_features[:, 0].mean().item()
new_node_features = torch.full((forecast_horizon, 1), historical_mean, dtype=torch.float)

new_edges = [[i, i + 1] for i in range(num_nodes - 1, num_nodes + forecast_horizon - 1)]
new_edges += [[i + 1, i] for i in range(num_nodes - 1, num_nodes + forecast_horizon - 1)]
extended_edge_index = torch.cat([edge_index, torch.tensor(new_edges, dtype=torch.long).t()], dim=1)
extended_node_features = torch.cat([node_features, new_node_features], dim=0)

model.eval()
extended_predictions = model(extended_node_features, extended_edge_index).detach().numpy()

# Prepare forecast years
forecast_years = range(int(years[-1].item()) + 1, int(years[-1].item()) + 1 + forecast_horizon)
forecast_values = extended_predictions[-forecast_horizon:]

# Visualize results
plt.figure(figsize=(12, 6))
# Use years[:len(y)] to match the dimensions of y and predictions
plt.plot(years[:len(y)], y.numpy(), label='Actual', marker='o')
plt.plot(years[:len(predictions)], predictions, label='Predicted', marker='x')
plt.plot(forecast_years, forecast_values, label='Forecast', marker='*', linestyle='--')
plt.xlabel('Year')
plt.ylabel('Cereal Yield (kg per hectare)')
plt.title('GNN Prediction and Forecast of Cereal Yield')
plt.legend()
plt.show()

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# --- Improved Forecast Initialization ---
def exponential_smoothing_initializer(historical_data, forecast_horizon):
    """Initialize future nodes using Holt-Winters exponential smoothing."""
    model = ExponentialSmoothing(historical_data.numpy(), trend='add', seasonal=None)
    fit = model.fit()
    return torch.tensor(fit.forecast(forecast_horizon), dtype=torch.float).view(-1, 1)

# Replace mean with smoothed forecasts
new_node_features = exponential_smoothing_initializer(node_features[:, 0], forecast_horizon)

# --- Time-Decaying Edge Weights (Optional) ---
def add_decaying_edges(num_nodes, forecast_horizon, decay_rate=0.9):
    """Edges lose influence exponentially over time."""
    new_edges = []
    edge_weights = []
    for i in range(num_nodes - 1, num_nodes + forecast_horizon - 1):
        new_edges.append([i, i + 1])
        new_edges.append([i + 1, i])
        edge_weights.extend([decay_rate**(i+1), decay_rate**(i+1)]) 
    return torch.tensor(new_edges).t(), torch.tensor(edge_weights)

extended_edge_index, edge_weight = add_decaying_edges(num_nodes, forecast_horizon)
extended_edge_index = torch.cat([edge_index.long(), extended_edge_index], dim=1)

# --- Monte Carlo Dropout for Uncertainty (PyTorch) ---
def mc_dropout_predict(model, x_test, edge_index): # Enable dropout at test time!
     model.train() 
     predictions = [model(x_test, edge_index).detach().numpy() for _ in range(100)] # Stochastic forward passes 
     return np.stack(predictions)

mc_predictions = mc_dropout_predict(model.eval(), extended_node_features, extended_edge_index)
mean_preds = mc_predictions.mean(axis=0)[-forecast_horizon:]
std_preds = mc_predictions.std(axis=0)[-forecast_horizon:]

# --- Visualization with Confidence Intervals ---
plt.figure(figsize=(12,6))
plt.plot(years[:len(y)], y.numpy(), label='Actual', marker='o')
plt.plot(years[:len(predictions)], predictions, label='Predicted', marker='x')
plt.plot(forecast_years[-10:], mean_preds, label='Forecast', marker='*', linestyle='--')
plt.fill_between(
     forecast_years[-10:],
     mean_preds.squeeze() - std_preds.squeeze(),
     mean_preds.squeeze() + std_preds.squeeze(),
     alpha=0.2,
 )
